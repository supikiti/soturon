# %%
# %load_ext autoreload
# %matplotlib inline
# %autoreload 
import matplotlib.pyplot as plt
import sklearn
import pandas as pd
import numpy as np
import librosa
from librosa.core.spectrum import _spectrogram

# %%
# load data
df_resampled = pd.read_pickle("./data_for_modeling.pickle")

# %%
df_resampled = df_resampled[df_resampled['tp'] < (0.01 / 1000) / 3600]

# %%
# しぶき
th = 1.0
while th > 10**(-10):
    print("総量:{} しぶき判定:{} {}以下の飛沫:{}".format(len(df_resampled), 
                                          len(df_resampled[df_resampled['SPC_flux[mm]'] != 0]), 
                                          th,
                                          len(df_resampled[df_resampled['SPC_flux[mm]'] != 0][df_resampled['SPC_flux[mm]'] < th])))
    th = th * 0.1
# Out:
# /home/nt/Desktop/soturon/soturon/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# 総量:944088 しぶき判定:46491 1.0以下の飛沫:21792
# 総量:944088 しぶき判定:46491 0.1以下の飛沫:5835
# 総量:944088 しぶき判定:46491 0.010000000000000002以下の飛沫:0
# 総量:944088 しぶき判定:46491 0.0010000000000000002以下の飛沫:0
# 総量:944088 しぶき判定:46491 0.00010000000000000003以下の飛沫:0
# 総量:944088 しぶき判定:46491 1.0000000000000004e-05以下の飛沫:0
# 総量:944088 しぶき判定:46491 1.0000000000000004e-06以下の飛沫:0
# 総量:944088 しぶき判定:46491 1.0000000000000005e-07以下の飛沫:0
# 総量:944088 しぶき判定:46491 1.0000000000000005e-08以下の飛沫:0
# 総量:944088 しぶき判定:46491 1.0000000000000005e-09以下の飛沫:0
# 総量:944088 しぶき判定:46491 1.0000000000000006e-10以下の飛沫:0

# %%
df_copy = df_resampled.copy()
# 飛沫データのラベリング
spray_all = np.array(df_copy['SPC_flux[mm]'])
# 飛沫発生ならlabel=1, 飛沫0.0ならlabel=0
spc_label = [1 if i > 1.0 else 0 for i in spray_all]
df_copy['label'] = spc_label

# %%
print(len(df_copy), len(df_copy[df_copy['label'] != 0.0]), len(df_copy[df_copy['label'] != 0.0]) / len(df_copy) * 100)
# Out:
# 944088 24699 2.616175610748151

# %% [markdown]
# # 1次元histgram

# %%
for_hist_list = ['encounter cycle', 'ピッチ (度)', 'Speed[knot]', 'relative_wind_y', 'swh']
for_hist_name = ['Average encounter\nperiod[s]', 'Pitch amplitude[deg]', 'Ship speed[knot]',
                          'Wind speed\nfrom bow direction[m/s]', 'Significant wave\nheight[m]']

from matplotlib import rcParams
#import japanize_matplotlib


# 1次元histを描画
def draw_1dhist(df, cols, name, file_name):
    plt.subplots_adjust(wspace=1.1, hspace=0.8)
    for i, col in enumerate(cols):
        plt.subplot(2, 3, i+1)
        plt.hist(df[col])
        plt.title(name[i])
    plt.savefig(file_name)
    plt.show()
    
def draw_1dhist_test(df, cols, name, file_name):
    fig, ax = plt.subplots(2, 3, figsize=(10, 5))
    plt.subplots_adjust(wspace=0.4, hspace=0.8)
    for i, col in enumerate(cols):
        ax[i%2, i%3].hist(df[col])
        ax[i%2, i%3].set_title(name[i])
    ax[1, 2].tick_params(labelbottom=False,
                                                  bottom=False,
                                                 labelleft=False,
                                                 left=False)
    ax[1, 2].spines["right"].set_color("none")  # 右消し
    ax[1, 2].spines["left"].set_color("none")   # 左消し
    ax[1, 2].spines["top"].set_color("none")    # 上消し
    ax[1, 2].spines["bottom"].set_color("none") # 下消し
    plt.savefig(file_name)
    plt.show()
    
hist_path = "./1dhist_shirase_fixed.png"
draw_1dhist_test(df_resampled, for_hist_list, for_hist_name, hist_path)

# %% [markdown]
# # 2次元histgram

# %%
spc_data = df_resampled['SPC_flux[mm]']
for_2dhist_plot = [ 'Significant wave\nheight[m]', 'Ship speed[knot]', 'Pitch amplitude[deg]', 
                     'Wind direction\nrelative to ship cource[deg]', 'Wind speed\nrelative to ship speed[m/s]', 'Wind speed\nfrom bow direction[m/s]',
                          'Average encounter period[s]']
extracted_data = ['swh', 'Speed[knot]', 'ピッチ (度)', 'Relative_wind_direction[deg]',
                           'Relative wind speed[m/s]', 'relative_wind_y', 'encounter cycle']

# %%
df_resampled['SPC_flux[mm]'].describe()
# Out:
# count    944088.000000
# mean          0.411585
# std           8.368078
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        3355.434515
# Name: SPC_flux[mm], dtype: float64

# %%
from matplotlib import rcParams,colors

num=2
plt.subplots_adjust(wspace=0.2, hspace=13)
rcParams.update({'font.size': 10})
fig = plt.figure(figsize=(8, 5), facecolor='w', edgecolor='k')

for i, col in enumerate(extracted_data):
    plt.subplot(3, 3, i+1)
    plt.subplots_adjust(wspace=0.5, hspace=1.4)
    plt.hist2d(df_resampled[col], spc_data,
                   bins=40, norm=colors.LogNorm(vmin=1, vmax=150))
    plt.xlabel(for_2dhist_plot[i])
    plt.ylabel('SPC[mm]')
    plt.colorbar()
    plt.ylim([0, 1000])
plt.savefig("./2dhist_shirase.png")
plt.show()

# %%
df_resampled.to_csv('data.csv', sep='\t')

# %% [markdown]
# # いろいろ

# %%
shirase_spc = df_resampled

# %%
plt.subplots_adjust(wspace=1.1, hspace=2)
show = ['ピッチ (度)', 'relative_wind_y', 'tp', 'swh', 'SPC_flux[mm]', 'label']
plt.figure(figsize=(15, 5))
start = 0
for i, s in enumerate(show):
    #plt.subplots_adjust(wspace=1.1, hspace=0.5)
    plt.subplot(len(show), 1, i+1)
    #plt.plot(np.arange(len(shirase_spc.ix[start:start+7200, :])), shirase_spc.ix[start:start+7200, :][s])
    plt.plot(np.arange(len(shirase_spc)), shirase_spc[s])

print("総サンプル数：", len(shirase_spc['SPC_flux[mm]']))
#th = 4.855319e-07
#tmp = shirase_spc[shirase_spc['tp'] <= th / 3600]['SPC_flux[mm]']
print("しぶき観測あり", len(shirase_spc[shirase_spc['label'] == 1]))
print("割合：{} %".format(len(shirase_spc[shirase_spc['label'] == 1]) / len(shirase_spc['label']) * 100))
# Out:
# 総サンプル数： 944088
# しぶき観測あり 46491
# 割合：4.9244350102956505 %

# %%
# 相対風速が正の数
print("相対風速が正の割合", len(shirase_spc), len(shirase_spc[shirase_spc['relative_wind_y'] >= 0.0]), 
      len(shirase_spc[shirase_spc['relative_wind_y'] >= 0.0]) / len(shirase_spc) * 100, "%")

for i in range(35):
    tmp = shirase_spc[shirase_spc['relative_wind_y'] >= i]
    print("相対風速が", str(i), len(tmp), len(tmp[tmp['label'] != 0.0]), 
          "しぶきが発生する割合", len(tmp[tmp['label'] != 0.0]) / len(tmp) * 100, "%", 
          "しぶきが発生しない割合", len(tmp[tmp['label'] == 0.0]) / len(tmp) * 100, "%")
# Out:
# 相対風速が正の割合 2653901 1456385 54.877141234733315 %
# 相対風速が 0 1456385 262280 しぶきが発生する割合 18.008974275346148 % しぶきが発生しない割合 81.99102572465385 %
# 相対風速が 1 1347831 248089 しぶきが発生する割合 18.406536131013457 % しぶきが発生しない割合 81.59346386898653 %
# 相対風速が 2 1234089 233120 しぶきが発生する割合 18.890047638379404 % しぶきが発生しない割合 81.1099523616206 %
# 相対風速が 3 1118757 217476 しぶきが発生する割合 19.439073900766655 % しぶきが発生しない割合 80.56092609923334 %
# 相対風速が 4 1006524 201824 しぶきが発生する割合 20.05158346944534 % しぶきが発生しない割合 79.94841653055467 %
# 相対風速が 5 899926 186119 しぶきが発生する割合 20.6815893751264 % しぶきが発生しない割合 79.31841062487361 %
# 相対風速が 6 795378 169886 しぶきが発生する割合 21.35915250358949 % しぶきが発生しない割合 78.64084749641052 %
# 相対風速が 7 698054 153443 しぶきが発生する割合 21.981537244969587 % しぶきが発生しない割合 78.01846275503041 %
# 相対風速が 8 607017 136739 しぶきが発生する割合 22.5263872346244 % しぶきが発生しない割合 77.4736127653756 %
# 相対風速が 9 520656 119832 しぶきが発生する割合 23.015580344795797 % しぶきが発生しない割合 76.9844196552042 %
# 相対風速が 10 442688 103506 しぶきが発生する割合 23.381252710712737 % しぶきが発生しない割合 76.61874728928726 %
# 相対風速が 11 371498 87849 しぶきが発生する割合 23.647233632482546 % しぶきが発生しない割合 76.35276636751746 %
# 相対風速が 12 310307 74399 しぶきが発生する割合 23.975933511006843 % しぶきが発生しない割合 76.02406648899316 %
# 相対風速が 13 257681 62471 しぶきが発生する割合 24.243541433012137 % しぶきが発生しない割合 75.75645856698786 %
# 相対風速が 14 215180 53021 しぶきが発生する割合 24.640301143228925 % しぶきが発生しない割合 75.35969885677108 %
# 相対風速が 15 178920 44445 しぶきが発生する割合 24.84071093226023 % しぶきが発生しない割合 75.15928906773978 %
# 相対風速が 16 145318 36680 しぶきが発生する割合 25.241195171967686 % しぶきが発生しない割合 74.75880482803231 %
# 相対風速が 17 116458 30940 しぶきが発生する割合 26.56751790345017 % しぶきが発生しない割合 73.43248209654983 %
# 相対風速が 18 91174 25061 しぶきが発生する割合 27.487002873626253 % しぶきが発生しない割合 72.51299712637375 %
# 相対風速が 19 70041 20201 しぶきが発生する割合 28.841678445481932 % しぶきが発生しない割合 71.15832155451807 %
# 相対風速が 20 54136 17160 しぶきが発生する割合 31.697945913994385 % しぶきが発生しない割合 68.30205408600561 %
# 相対風速が 21 43354 14824 しぶきが発生する割合 34.19292337500577 % しぶきが発生しない割合 65.80707662499424 %
# 相対風速が 22 35387 12734 しぶきが発生する割合 35.984966230536635 % しぶきが発生しない割合 64.01503376946336 %
# 相対風速が 23 28887 10784 しぶきが発生する割合 37.33167168622564 % しぶきが発生しない割合 62.66832831377436 %
# 相対風速が 24 23049 8974 しぶきが発生する割合 38.93444401058615 % しぶきが発生しない割合 61.06555598941385 %
# 相対風速が 25 17238 7043 しぶきが発生する割合 40.85740805197819 % しぶきが発生しない割合 59.14259194802182 %
# 相対風速が 26 12164 5229 しぶきが発生する割合 42.98750411048997 % しぶきが発生しない割合 57.01249588951003 %
# 相対風速が 27 8169 3682 しぶきが発生する割合 45.072836332476435 % しぶきが発生しない割合 54.92716366752356 %
# 相対風速が 28 5028 2294 しぶきが発生する割合 45.62450278440732 % しぶきが発生しない割合 54.37549721559268 %
# 相対風速が 29 2893 1281 しぶきが発生する割合 44.279294849637054 % しぶきが発生しない割合 55.720705150362946 %
# 相対風速が 30 1484 648 しぶきが発生する割合 43.66576819407008 % しぶきが発生しない割合 56.334231805929925 %
# 相対風速が 31 713 277 しぶきが発生する割合 38.849929873772794 % しぶきが発生しない割合 61.150070126227206 %
# 相対風速が 32 235 83 しぶきが発生する割合 35.319148936170215 % しぶきが発生しない割合 64.68085106382979 %
# 相対風速が 33 87 23 しぶきが発生する割合 26.436781609195403 % しぶきが発生しない割合 73.5632183908046 %
# 相対風速が 34 27 5 しぶきが発生する割合 18.51851851851852 % しぶきが発生しない割合 81.48148148148148 %

# %%
tmp = shirase_spc[shirase_spc['relative_wind_y'] < 0.0]
print("相対風速が", str(i), len(tmp), len(tmp[tmp['label'] != 0.0]), 
          "しぶきが発生する割合", len(tmp[tmp['label'] != 0.0]) / len(tmp) * 100, "%", 
          "しぶきが発生しない割合", len(tmp[tmp['label'] == 0.0]) / len(tmp) * 100, "%")
# Out:
# 相対風速が 34 1197516 204637 しぶきが発生する割合 17.08845643816033 % しぶきが発生しない割合 82.91154356183968 %

# %%
for i in range(5):
    tmp = shirase_spc[shirase_spc['swh'] >= i]
    print("有義波高", str(i), len(tmp), len(tmp[tmp['label'] != 0.0]), 
          "しぶきが発生する割合", len(tmp[tmp['label'] != 0.0]) / len(tmp) * 100, "%", 
          "しぶきが発生しない割合", len(tmp[tmp['label'] == 0.0]) / len(tmp) * 100, "%")
# Out:
# 有義波高 0 2653901 466917 しぶきが発生する割合 17.5936103117637 % しぶきが発生しない割合 82.4063896882363 %
# 有義波高 1 2632423 466668 しぶきが発生する割合 17.727698018137662 % しぶきが発生しない割合 82.27230198186234 %
# 有義波高 2 1904536 390664 しぶきが発生する割合 20.512292757921088 % しぶきが発生しない割合 79.48770724207891 %
# 有義波高 3 1130617 268416 しぶきが発生する割合 23.740665495035014 % しぶきが発生しない割合 76.259334504965 %
# 有義波高 4 308675 98359 しぶきが発生する割合 31.86490645500931 % しぶきが発生しない割合 68.13509354499068 %
